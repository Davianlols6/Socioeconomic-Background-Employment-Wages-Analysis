# %%
import os
os.chdir('C:\\Users\\davia\\OneDrive - Singapore Polytechnic\\SP\\Year 1 Sem 2\\ST1510 (PDAS) Programming for Data Analytics\\CA2\\Datasets')

# %%
# Import Modules

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ### How does a person’s socioeconomic background affect their employment opportunities and the wages they get?

# %%
# Importing Mean Monthly Nominal Earnings Per Employee By Sex Dataset
# https://beta.data.gov.sg/collections/643/view

meanEarningsBySex = pd.read_csv('AverageMeanMonthlyNominalEarningsPerEmployeeBySexQuarterly.csv')

print('Information about Average Mean Monthly Nominal Earnings Per Employee By Sex Quarterly Dataset\n')

print(f'This dataset has {meanEarningsBySex.shape[0]} rows and {meanEarningsBySex.shape[1]} columns', end='\n\n')

print('Column Data:')
for i in meanEarningsBySex.columns:
    print(f'- Name: {i} | Data Type: {meanEarningsBySex[i].dtypes} | Amount Of Null Values: {meanEarningsBySex[i].isnull().sum()}')

print("\nDataset Sample:")
print(meanEarningsBySex.head(5))
# Out:
# Information about Average Mean Monthly Nominal Earnings Per Employee By Sex Quarterly Dataset
#
# This dataset has 309 rows and 3 columns
#
# Column Data:
# - Name: quarter | Data Type: object | Amount Of Null Values: 0
# - Name: sex | Data Type: object | Amount Of Null Values: 0
# - Name: average_monthly_earnings | Data Type: int64 | Amount Of Null Values: 0
#
# Dataset Sample:
#    quarter    sex  average_monthly_earnings
# 0  1998-Q1  total                      2800
# 1  1998-Q2  total                      2544
# 2  1998-Q3  total                      2511
# 3  1998-Q4  total                      3104
# 4  1999-Q1  total                      2793

# %%
# Importing Median Monthly Basic and Gross Wages of Common Occupations by Sex in All Industries Dataset
# https://beta.data.gov.sg/collections/671/datasets/d_a0a2ee53ade228095be6b86cf1eb43df/view

medianWageOfOccupationsbySexinAllIndustries = pd.read_csv('wage_01_sex2_annual.csv')

print('Information about Median Monthly Basic and Gross Wages of Common Occupations by Sex in All Industries Dataset\n')

print(f'This dataset has {medianWageOfOccupationsbySexinAllIndustries.shape[0]} rows and {medianWageOfOccupationsbySexinAllIndustries.shape[1]} columns', end='\n\n')

print('Column Data:')
for i in medianWageOfOccupationsbySexinAllIndustries.columns:
    print(f'- Name: {i} | Data Type: {medianWageOfOccupationsbySexinAllIndustries[i].dtypes} | Amount Of Null Values: {medianWageOfOccupationsbySexinAllIndustries[i].isnull().sum()}')

print("\nDataset Sample:")
print(medianWageOfOccupationsbySexinAllIndustries.head(5))
# Out:
# Information about Median Monthly Basic and Gross Wages of Common Occupations by Sex in All Industries Dataset
#
# This dataset has 528 rows and 6 columns
#
# Column Data:
# - Name: year | Data Type: int64 | Amount Of Null Values: 0
# - Name: occ_desc | Data Type: object | Amount Of Null Values: 0
# - Name: sex1 | Data Type: object | Amount Of Null Values: 0
# - Name: sex2 | Data Type: object | Amount Of Null Values: 0
# - Name: mthly_gross_wage_50_pctile | Data Type: int64 | Amount Of Null Values: 0
# - Name: mthly_basic_wage_50_pctile | Data Type: int64 | Amount Of Null Values: 0
#
# Dataset Sample:
#    year                                           occ_desc sex1     sex2  \
# 0  2022          managing director/chief executive officer  all  females
# 1  2022          managing director/chief executive officer  all    males
# 2  2022            chief operating officer/general manager  all  females
# 3  2022            chief operating officer/general manager  all    males
# ...

# %%
# Importing Unemployed Residents Aged 15 Years and Over by Highest Qualification Attained, Age And Sex Dataset
# https://beta.data.gov.sg/collections/1922/view

unemployedResidentsByHighestQualificationAttained = pd.read_csv('UnemployedResidentsAged15YearsandOverbyHighestQualificationAttainedAgeAndSex.csv')

print('Information about Unemployed Residents Aged 15 Years and Over by Highest Qualification Attained, Age And Sex Dataset\n')

print(f'This dataset has {unemployedResidentsByHighestQualificationAttained.shape[0]} rows and {unemployedResidentsByHighestQualificationAttained.shape[1]} columns', end='\n\n')

print('Column Data:')
for i in unemployedResidentsByHighestQualificationAttained.columns:
    print(f'- Name: {i} | Data Type: {unemployedResidentsByHighestQualificationAttained[i].dtypes} | Amount Of Null Values: {unemployedResidentsByHighestQualificationAttained[i].isnull().sum()}')

print("\nDataset Sample:")
print(unemployedResidentsByHighestQualificationAttained.head(5))
# Out:
# Information about Unemployed Residents Aged 15 Years and Over by Highest Qualification Attained, Age And Sex Dataset
#
# This dataset has 624 rows and 5 columns
#
# Column Data:
# - Name: year | Data Type: int64 | Amount Of Null Values: 0
# - Name: sex | Data Type: object | Amount Of Null Values: 0
# - Name: age | Data Type: object | Amount Of Null Values: 0
# - Name: highest_qualification | Data Type: object | Amount Of Null Values: 0
# - Name: unemployed | Data Type: int64 | Amount Of Null Values: 0
#
# Dataset Sample:
#    year   sex    age                   highest_qualification  unemployed
# 0  2010  male  15-29                       primary and below         500
# 1  2010  male  15-29                         lower secondary        1200
# 2  2010  male  15-29                               secondary        3300
# 3  2010  male  15-29           post-secondary (non-tertiary)        3100
# 4  2010  male  15-29  diploma and professional qualification        3400

# %%
# Importing Overall Unemployment Rate, Annual Dataset
# https://beta.data.gov.sg/collections/2119/datasets/d_e3598914c86699a9a36e68190f78c59a/view

overallUnemploymentRate = pd.read_csv('OverallUnemploymentRateAnnual.csv')

print('Information about Overall Unemployment Rate Annual Dataset\n')

print(f'This dataset has {overallUnemploymentRate.shape[0]} rows and {overallUnemploymentRate.shape[1]} columns', end='\n\n')

print('Column Data:')
for i in overallUnemploymentRate.columns:
    print(f'- Name: {i} | Data Type: {overallUnemploymentRate[i].dtypes} | Amount Of Null Values: {overallUnemploymentRate[i].isnull().sum()}')

print("\nDataset Sample:")
print(overallUnemploymentRate.head(5))
# Out:
# Information about Overall Unemployment Rate Annual Dataset
#
# This dataset has 31 rows and 3 columns
#
# Column Data:
# - Name: year | Data Type: int64 | Amount Of Null Values: 0
# - Name: residential_status | Data Type: object | Amount Of Null Values: 0
# - Name: unemployment_rate | Data Type: float64 | Amount Of Null Values: 0
#
# Dataset Sample:
#    year residential_status  unemployment_rate
# 0  1992            overall                1.8
# 1  1993            overall                1.7
# 2  1994            overall                1.7
# 3  1995            overall                1.8
# 4  1996            overall                1.7

# %%
# Importing Basic Wage Change Dataset
# https://beta.data.gov.sg/collections/662/datasets/d_a73c27669241db5833f5cd23057141c5/view

basicWageChange = pd.read_csv('BasicWageChangeTotal.csv')

print('Information about Basic Wage Change Dataset\n')

print(f'This dataset has {basicWageChange.shape[0]} rows and {basicWageChange.shape[1]} columns', end='\n\n')

print('Column Data:')
for i in basicWageChange.columns:
    print(f'- Name: {i} | Data Type: {basicWageChange[i].dtypes} | Amount Of Null Values: {basicWageChange[i].isnull().sum()}')

print("\nDataset Sample:")
print(basicWageChange.head(5))
# Out:
# Information about Basic Wage Change Dataset
#
# This dataset has 22 rows and 2 columns
#
# Column Data:
# - Name: year | Data Type: int64 | Amount Of Null Values: 0
# - Name: bwc | Data Type: float64 | Amount Of Null Values: 0
#
# Dataset Sample:
#    year  bwc
# 0  2001  2.9
# 1  2002  1.8
# 2  2003  1.2
# 3  2004  2.7
# 4  2005  3.1

# %%
# Importing Total Wage Change Dataset
# https://beta.data.gov.sg/collections/676/datasets/d_ae92f125ca6bf7e3bba260c137a68c79/view

totalWageChange = pd.read_csv('TotalWageChangeTotal.csv')

print('Information about Total Wage Change Dataset\n')

print(f'This dataset has {totalWageChange.shape[0]} rows and {totalWageChange.shape[1]} columns', end='\n\n')

print('Column Data:')
for i in totalWageChange.columns:
    print(f'- Name: {i} | Data Type: {totalWageChange[i].dtypes} | Amount Of Null Values: {totalWageChange[i].isnull().sum()}')

print("\nDataset Sample:")
print(totalWageChange.head(5))
# Out:
# Information about Total Wage Change Dataset
#
# This dataset has 22 rows and 2 columns
#
# Column Data:
# - Name: year | Data Type: int64 | Amount Of Null Values: 0
# - Name: twc | Data Type: float64 | Amount Of Null Values: 0
#
# Dataset Sample:
#    year  twc
# 0  2001  1.1
# 1  2002  0.0
# 2  2003  1.5
# 3  2004  3.6
# 4  2005  4.3

# %%
# Importing Resident Labour Force Aged 15 Years and Over by Labour Force Status, Age And Sex Dataset
# https://beta.data.gov.sg/collections/1921/view

labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex = pd.read_csv('ResidentLabourForceAged15YearsandOverbyLabourForceStatusAgeAndSex.csv')

print('Information about Resident Labour Force Aged 15 Years and Over by Labour Force Status Age And Sex Dataset\n')

print(f'This dataset has {labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex.shape[0]} rows and {labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex.shape[1]} columns', end='\n\n')

print('Column Data:')
for i in labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex.columns:
    print(f'- Name: {i} | Data Type: {labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex[i].dtypes} | Amount Of Null Values: {labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex[i].isnull().sum()}')

print("\nDataset Sample:")
print(labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex.head(5))
# Out:
# Information about Resident Labour Force Aged 15 Years and Over by Labour Force Status Age And Sex Dataset
#
# This dataset has 696 rows and 7 columns
#
# Column Data:
# - Name: year | Data Type: int64 | Amount Of Null Values: 0
# - Name: sex | Data Type: object | Amount Of Null Values: 0
# - Name: age | Data Type: object | Amount Of Null Values: 0
# - Name: labour_force | Data Type: int64 | Amount Of Null Values: 0
# - Name: employed | Data Type: int64 | Amount Of Null Values: 0
# - Name: unemployed | Data Type: object | Amount Of Null Values: 0
# - Name: outside_labour_force | Data Type: int64 | Amount Of Null Values: 0
#
# Dataset Sample:
#    year   sex    age  labour_force  employed unemployed  outside_labour_force
# 0  1991  male  15-19         36900     35700       1300                 86000
# 1  1991  male  20-24         99400     96400       3000                 21500
# 2  1991  male  25-29        134500    131000       3500                  4300
# ...

# %% [markdown]
# ### Does a person's gender affect the wages they get?

# %%
# Copy the dataset so as to not alter the original dataset
meanEarningsBySex_copy = meanEarningsBySex.copy()

# Pivoting the table
meanEarningsBySex_copy = meanEarningsBySex_copy.pivot(index='quarter', columns='sex', values='average_monthly_earnings')

import matplotlib.pyplot as plt
plt.figure(figsize=(16,9))

# Plot the dataset
plt.plot(meanEarningsBySex_copy['male'], marker='o', label='Male')
plt.plot(meanEarningsBySex_copy['female'], marker='o', label='Female')

plt.legend()
plt.title("Mean Earnings By Sex")

plt.xticks(rotation=90)
plt.xlabel("Quater")
plt.ylabel("Earnings ($)")
plt.show()

# %% [markdown]
# We can see that male workers earn a higher wage on average compared to their female counterparts. We can also see that the average earnings for both genders are on an increasing trend. We can also see that the mean salary usually rise and fall around Quarter 4 and Quarter 1.
#
# One possible explanation for this fluctuation is that bonuses are usually given out at the end or at the start of the year, therefore and increase in the mean salary during these periods of the year is expected.

# %%
meanEarningsBySex_copy['gender_difference'] = meanEarningsBySex_copy['male'] - meanEarningsBySex_copy['female']

import matplotlib.pyplot as plt
plt.figure(figsize=(16,9))
# Plot the dataset
plt.plot(meanEarningsBySex_copy['gender_difference'], marker='o', label='Difference')
plt.legend()
plt.title("Difference In Earnings Between Males And Females")

plt.xticks(rotation=90, fontsize=8)
plt.xlabel("Quater")
plt.ylabel("Earnings ($)")
plt.show()

# %% [markdown]
# We can see that the difference in the wage gap between males and females was initially on an increasing trend from 1988 to about 2014 but stopped and remained stable there from 2014 till 2023.
#
# The difference in pay between both genders in recent years are between $1.2k to $1.6k

# %% [markdown]
# ### Wage breakdown by industry

# %%
# Copy the dataset so as to not alter the original dataset
medianWageOfOccupationsbySexinAllIndustries_copy = medianWageOfOccupationsbySexinAllIndustries.copy()

# Get rid of occupation which only has data for 1 gender
medianWageOfOccupationsbySexinAllIndustries_copy = medianWageOfOccupationsbySexinAllIndustries_copy[medianWageOfOccupationsbySexinAllIndustries_copy['occ_desc'].duplicated(keep=False)]

# Pivoting the table
medianWageOfOccupationsbySexinAllIndustries_copy = medianWageOfOccupationsbySexinAllIndustries_copy.pivot_table(index='occ_desc', columns='sex2', values='mthly_basic_wage_50_pctile', aggfunc='first')

# Calculating the wage gap per industry
medianWageOfOccupationsbySexinAllIndustries_copy['wage_difference'] = abs(medianWageOfOccupationsbySexinAllIndustries_copy['males'] - medianWageOfOccupationsbySexinAllIndustries_copy['females'])

# Sort rows by wage_difference
medianWageOfOccupationsbySexinAllIndustries_copy.sort_values('wage_difference', inplace=True, ascending=False)

# Getting the top 10 industries with the biggest and smallest pay gap
medianWageOfOccupationsbySexinAllIndustries_copy_top10 = medianWageOfOccupationsbySexinAllIndustries_copy.head(10)
medianWageOfOccupationsbySexinAllIndustries_copy_bottom10 = medianWageOfOccupationsbySexinAllIndustries_copy.tail(10)[::-1]

# Plot the dataset
import matplotlib.pyplot as plt

x = np.arange(len(medianWageOfOccupationsbySexinAllIndustries_copy_top10))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, (ax, ax2) = plt.subplots(1,2,layout='constrained')
fig.set_size_inches(16, 9)

for attribute, measurement in medianWageOfOccupationsbySexinAllIndustries_copy_top10[['males', 'females']].items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Salary ($)')
ax.set_xlabel('Industry')
ax.set_title('Top 10 Professions With The Biggest Gender Pay Gap')
ax.set_xticks(x + width, medianWageOfOccupationsbySexinAllIndustries_copy_top10.index, rotation=90)
ax.legend(loc='upper left', ncols=3)

multiplier = 0

for attribute, measurement in medianWageOfOccupationsbySexinAllIndustries_copy_bottom10[['males', 'females']].items():
    offset = width * multiplier
    rects = ax2.bar(x + offset, measurement, width, label=attribute)
    ax2.bar_label(rects, )
    multiplier += 1

ax2.set_ylabel('Salary ($)')
ax2.set_xlabel('Industry')
ax2.set_title('Top 10 Professions With The Smallest Gender Pay Gap')
ax2.set_xticks(x + width, medianWageOfOccupationsbySexinAllIndustries_copy_bottom10.index, rotation=90)
ax2.legend(loc='upper left', ncols=3)
plt.show()

# %% [markdown]
# We can see that the industry with the highest gender pay gap are mostly finance related and are usually high paying jobs like sales professionals, fund/portfolio manager and the likes. Industries with higher gender pay gap are usually considered high-level jobs and have higher pay. On the other end, industries with the smallest gender pay gap are those usually considered to be low-level like table-top cleaner, security supervisor and dishwasher.

# %% [markdown]
# ### Unemployment By Highest Qualification Attained

# %%
# Copy the dataset so as to not alter the original dataset
unemployedResidentsByHighestQualificationAttained_copy = unemployedResidentsByHighestQualificationAttained.copy()

# Group by 'year', 'sex', and 'highest_qualification' and sum the 'labour_force'
result = unemployedResidentsByHighestQualificationAttained_copy.groupby(['year', 'highest_qualification'], as_index=False)['unemployed'].sum()

# Getting the x-values for each qualifications
highest_qualification_degree = result[result['highest_qualification'] == 'degree']
highest_qualification_diploma = result[result['highest_qualification'] == 'diploma and professional qualification']
highest_qualification_lower_secondary = result[result['highest_qualification'] == 'lower secondary']
highest_qualification_post_sec = result[result['highest_qualification'] == 'post-secondary (non-tertiary)']
highest_qualification_primary_and_below = result[result['highest_qualification'] == 'primary and below']
highest_qualification_secondary = result[result['highest_qualification'] == 'secondary']

import matplotlib.pyplot as plt
plt.figure(figsize=(16,9))

# Plot the dataset
plt.plot(highest_qualification_degree['year'], highest_qualification_degree['unemployed'], marker='o', label='Degree')
plt.plot(highest_qualification_degree['year'], highest_qualification_diploma['unemployed'], marker='o', label='Diploma')
plt.plot(highest_qualification_degree['year'], highest_qualification_lower_secondary['unemployed'], marker='o', label='Lower Secondary')
plt.plot(highest_qualification_degree['year'], highest_qualification_post_sec['unemployed'], marker='o', label='Post Secondary')
plt.plot(highest_qualification_degree['year'], highest_qualification_primary_and_below['unemployed'], marker='o', label='Primary And Below')
plt.plot(highest_qualification_degree['year'], highest_qualification_secondary['unemployed'], marker='o', label='Secondary')

plt.legend()
plt.title("Unemployment By Highest Qualification Attained")

plt.xlabel("Years")
plt.ylabel("Unemployed")
plt.ticklabel_format(style='plain') 
plt.show()

# %% [markdown]
# We can see that the unemployment rate for degree and diploma holders have been on an increasing trend since 2010 while other qualifications have remained stable or even decreased. This is unexpected as we would expect that degree or diploma holders would have a lower unemployment rate due to their high qualifications. One possible reason for this would be that there is an oversaturation of degree and diploma holders.

# %% [markdown]
# ### How does age affect employment opportunities?

# %%
# Copy the dataset so as to not alter the original dataset
labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy = labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex.copy()

# Get only useful columns
labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy = labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy[labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex.year == 2022][['age', 'labour_force', 'outside_labour_force']]

# Group by the dataset by age
labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy = labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy.groupby(['age'], as_index=False).sum()

# Melt the table
labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy = pd.melt(labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy, id_vars=['age'], var_name='category', value_name='value')

import matplotlib.pyplot as plt
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8), (ax9, ax10, ax11, ax12)) = plt.subplots(3, 4, figsize=(16,9))

axList = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12]

count = 0
for i in labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy['age'].unique():
    ax = axList[count]
    x = labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy[labourForceAged15YearsandOverbyLabourForceStatusAgeAndSex_copy['age'] == i]
    ax.pie(x['value'], labels=x['category'], autopct='%1.1f%%')
    ax.set_title(f"Labour Force Participation\nBy Age {i}")
    count += 1

# %% [markdown]
# As we can see from the pie charts above, only a minority, 15.9% of youths aged 15 to 19 are working. This is expected as the majority of youth in that age range are currently still studying full time. The labour force aged 25-29 shows the completely opposite result with the minority, 10.7% of that age group outside of the work force. From ages 25-29 onwards, the proportions of labour force participations remains roughly the same until the ages 50-54 where the proportion of those outside the work force starts to grow. This is expected as from that age group onwards, people would start to retire. The biggest jump in outside work force proportion is from age 60-64 to age 65-69 from 32.5& to 50.6%. This is expected as the retiring age in Singapore is 63 years old. Only 21.8% of those 70 and over are still working.

# %% [markdown]
# ### How does unemployment rate affect wages?

# %% [markdown]
# #### How does unemployment rate affect total wage changes?

# %%
# Copy the dataset so as to not alter the original dataset
overallUnemploymentRate_copy = overallUnemploymentRate.copy()
totalWageChange_copy = totalWageChange.copy()

# Drop unnecessary columns
overallUnemploymentRate_copy.drop('residential_status', inplace=True, axis=1)

# Merge with total wage change dataset
overallUnemploymentRate_copy = overallUnemploymentRate_copy.merge(totalWageChange_copy, on='year', how='inner')

# Get the OLS regression result
unemploymentRateByTWC = smf.ols(formula='unemployment_rate ~ twc', data=overallUnemploymentRate_copy).fit()

# %%
print(unemploymentRateByTWC.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      unemployment_rate   R-squared:                       0.465
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     17.39
# Date:                Mon, 05 Feb 2024   Prob (F-statistic):           0.000473
# Time:                        23:09:27   Log-Likelihood:                -12.738
# No. Observations:                  22   AIC:                             29.48
# Df Residuals:                      20   BIC:                             31.66
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3200      0.216     15.360      0.000       2.869       3.771
# ...

# %%
x=overallUnemploymentRate_copy['unemployment_rate']
y=overallUnemploymentRate_copy['twc']

import matplotlib.pyplot as plt
fig1, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,9))

# matplotlib scatterplot
ax1.scatter(y=y, x=x)
# best fit line Y = C + M * X
m,c = np.polyfit(x, y, deg=1)
ax1.plot(x, c+m*x, 'r-')
ax1.set_xlabel('Unemployment Rate')
ax1.set_ylabel('Total Wage Change')

ax1.set_title("Total Wage Changes vs Unemployment Rate")

linearModEq = "Y = {:.5} {:.5}X".format(unemploymentRateByTWC.params[0],unemploymentRateByTWC.params[1])
ax1.annotate(linearModEq, xy=(2.3, 4.109937740883488), xytext=(2.5,5), size=12, arrowprops=dict(facecolor='green', shrink=0.05))

sns.histplot(overallUnemploymentRate_copy['twc'], kde=True, ax=ax2)
sm.qqplot(overallUnemploymentRate_copy['twc'], line='s', ax=ax3)

plt.show()

# %% [markdown]
# Total wage change includes bonuses along with the basic pay.
# With a squared value of 0.465, we can see that there is a moderate negative relationship between the total wage change and unemployment rate. This goes to show that as the unemployment rate rises, wages rises at a slower pace and lesser bonuses is given out, which is to be expected.
# For every one percent increase in unemployment rate, the total wage change decreases by 0.22%.
# The distribution is not close to normal as can be seen in the histogram and Q-Q plot. Which can lead to the model not fitting well to the dataset.

# %% [markdown]
# #### How does unemployment rate affect basic wage changes?

# %%
# Copy the dataset so as to not alter the original dataset
overallUnemploymentRate_copy = overallUnemploymentRate.copy()
basicWageChange_copy = basicWageChange.copy()

# Drop unnecessary columns
overallUnemploymentRate_copy.drop('residential_status', inplace=True, axis=1)

# Merge with basic wage change dataset
overallUnemploymentRate_copy = overallUnemploymentRate_copy.merge(basicWageChange_copy, on='year', how='inner')

# Get the OLS regression result
unemploymentRateByBWC = smf.ols(formula='unemployment_rate ~ bwc', data=overallUnemploymentRate_copy).fit()

# %%
print(unemploymentRateByBWC.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      unemployment_rate   R-squared:                       0.790
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     75.14
# Date:                Mon, 05 Feb 2024   Prob (F-statistic):           3.30e-08
# Time:                        23:09:29   Log-Likelihood:                -2.4645
# No. Observations:                  22   AIC:                             8.929
# Df Residuals:                      20   BIC:                             11.11
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.1668      0.200     20.825      0.000       3.749       4.584
# ...

# %%
x=overallUnemploymentRate_copy['unemployment_rate']
y=overallUnemploymentRate_copy['bwc']

import matplotlib.pyplot as plt
fig1, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,9))

# matplotlib scatterplot
ax1.scatter(y=y, x=x)
# best fit line Y = C + M * X
m,c = np.polyfit(x, y, deg=1)
ax1.plot(x, c+m*x, 'r-')
ax1.set_xlabel('Unemployment Rate')
ax1.set_ylabel('Basic Wage Change')

linearModEq = "Y = {:.5} {:.5}X".format(unemploymentRateByTWC.params[0],unemploymentRateByTWC.params[1])
ax1.set_title("Basic Wage Changes vs Unemployment Rate")
ax1.annotate(linearModEq, xy=(2.3, 3.887281351912246), xytext=(2.5,5), size=12, arrowprops=dict(facecolor='green', shrink=0.05))

sns.histplot(overallUnemploymentRate_copy['bwc'], kde=True, ax=ax2)
sm.qqplot(overallUnemploymentRate_copy['bwc'], line='s', ax=ax3)

plt.show()

# %% [markdown]
# With an r-sqaured value of 0.79, we can see that there is a strong negative relationship between the basic wage change and unemployment rate. For every one percent increase in unemployment rate, the basic wage change decreases by 0.22%. This goes to show that as the unemployment rate rises, wages rises at a slower pace which is to be expected. The distribution is not close to normal as can be seen in the histogram and Q-Q plot. Which can lead to the model not fitting well to the dataset.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - From our insights, we can conclude that there is a gender pay gap between males and female with males earning more than $1000 than females on average.
# - The industry you join and type of job you work determines whether you are more likely to be paid more or less than co-workers of the opposite gender.
# - Holding a degree or diploma does not guarantee you employment as degree and diploma holders have a higher proportion of unemployment.
# - As unemployment rates increase, basic and total salary increases at a slower pace.
